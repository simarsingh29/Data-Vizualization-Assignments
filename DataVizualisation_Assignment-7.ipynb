# %% [markdown]
# ## Implement a Naïve Bayes classifier using sklearn.naive_bayes

# %%
# Step 1: Import necessary libraries
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

# Step 2: Load dataset
iris = load_iris()
X = iris.data
y = iris.target

# Step 3: Split dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# Step 4: Initialize the Gaussian Naive Bayes model
model = GaussianNB()

# Step 5: Train the model on training data
model.fit(X_train, y_train)

# Step 6: Predict on the test data
y_pred = model.predict(X_test)

# Step 7: Evaluate the model
accuracy = accuracy_score(y_test, y_pred)

# Display results
print("Naive Bayes Classifier Results (GaussianNB)")
print("===========================================")
print("Actual Labels:   ", y_test)
print("Predicted Labels:", y_pred)
print("Accuracy Score:  {:.2f}%".format(accuracy * 100))
# Out:
# Naive Bayes Classifier Results (GaussianNB)
# ===========================================
# Actual Labels:    [1 0 2 1 1 0 1 2 1 1 2 0 0 0 0 1 2 1 1 2 0 2 0 2 2 2 2 2 0 0 0 0 1 0 0 2 1
#  0 0 0 2 1 1 0 0]
# Predicted Labels: [1 0 2 1 1 0 1 2 1 1 2 0 0 0 0 2 2 1 1 2 0 2 0 2 2 2 2 2 0 0 0 0 1 0 0 2 1
#  0 0 0 2 1 1 0 0]
# Accuracy Score:  97.78%
